# %%
import pandas as pd

# %%
state1= pd.read_csv('states1.csv')
state1
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
#
#                  White                Black                Native  \
# 0   69.89557165861504%   3.546376811594201%   0.5738325281803548%
# 1    67.6770531400966%   10.34806763285027%  0.12620772946859898%
# 2   64.63271028037383%  20.743925233644834%  0.25981308411214965%
# 3  33.103910614525134%   51.77653631284915%  0.20055865921787713%
# 4   59.08374880153398%  15.165675934803444%   0.2104506232023015%
# 5   54.28630556974962%   32.08829841594277%  0.18758303525804798%
#
# ...

# %%
state1.drop("Unnamed: 0", axis = 1)
# Out:
#                   State  TotalPop             Hispanic                White  \
# 0              Colorado   5278906   20.78438003220608%   69.89557165861504%
# 1           Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 2              Delaware    926454    8.82476635514019%   64.63271028037383%
# 3  District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 4               Florida  19645772    21.3385426653884%   59.08374880153398%
# 5               Georgia  10006693   8.418242207460397%   54.28630556974962%
#
#                  Black                Native                Asian  \
# 0   3.546376811594201%   0.5738325281803548%   2.661996779388082%
# 1   10.34806763285027%  0.12620772946859898%   4.021980676328502%
# 2  20.743925233644834%  0.25981308411214965%  3.2686915887850483%
# 3   51.77653631284915%  0.20055865921787713%  3.3832402234636865%
# 4  15.165675934803444%   0.2104506232023015%  2.2831735378715257%
# ...

# %%
state1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6 non-null      int64
#  1   State       6 non-null      object
#  2   TotalPop    6 non-null      int64
#  3   Hispanic    6 non-null      object
#  4   White       6 non-null      object
#  5   Black       6 non-null      object
#  6   Native      6 non-null      object
#  7   Asian       6 non-null      object
#  8   Pacific     4 non-null      object
#  9   Income      6 non-null      object
#  10  GenderPop   6 non-null      object
# dtypes: int64(2), object(9)
# memory usage: 660.0+ bytes

# %%
state1.shape
# Out:
# (6, 11)

# %%
state1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
state1.isna().sum()
# Out:
# Unnamed: 0    0
# State         0
# TotalPop      0
# Hispanic      0
# White         0
# Black         0
# Native        0
# Asian         0
# Pacific       2
# Income        0
# GenderPop     0
# dtype: int64

# %%
state1.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
state1.Hispanic = state1.Hispanic.str.replace("%"," "). astype(float)*100
state1.White  = state1.White.str.replace("%"," "). astype(float)*100
state1.Black  = state1.Black.str.replace("%"," "). astype(float)*100
state1.Native  = state1.Native.str.replace("%"," "). astype(float)*100
state1.Asian  = state1.Asian.str.replace("%"," "). astype(float)*100
state1.Pacific  = state1.Pacific.str.replace("%"," "). astype(float)*100

# %%
state1
# Out:
#    Unnamed: 0                 State  TotalPop     Hispanic        White  \
# 0           0              Colorado   5278906  2078.438003  6989.557166
# 1           1           Connecticut   3593222  1560.483092  6767.705314
# 2           2              Delaware    926454   882.476636  6463.271028
# 3           3  District of Columbia    647484   916.592179  3310.391061
# 4           4               Florida  19645772  2133.854267  5908.374880
# 5           5               Georgia  10006693   841.824221  5428.630557
#
#          Black     Native       Asian   Pacific               Income  \
# 0   354.637681  57.383253  266.199678       NaN  $64657.801787164906
# 1  1034.806763  12.620773  402.198068  1.859903    $76146.5605875153
# 2  2074.392523  25.981308  326.869159       NaN   $61827.97663551402
# 3  5177.653631  20.055866  338.324022  2.960894   $75466.36363636363
# 4  1516.567593  21.045062  228.317354  5.151007  $50690.194986743794
# ...

# %%
state1.Income = state1.Income.str.replace("$"," "). astype(float)

# %%
state1
# Out:
#    Unnamed: 0                 State  TotalPop     Hispanic        White  \
# 0           0              Colorado   5278906  2078.438003  6989.557166
# 1           1           Connecticut   3593222  1560.483092  6767.705314
# 2           2              Delaware    926454   882.476636  6463.271028
# 3           3  District of Columbia    647484   916.592179  3310.391061
# 4           4               Florida  19645772  2133.854267  5908.374880
# 5           5               Georgia  10006693   841.824221  5428.630557
#
#          Black     Native       Asian   Pacific        Income  \
# 0   354.637681  57.383253  266.199678       NaN  64657.801787
# 1  1034.806763  12.620773  402.198068  1.859903  76146.560588
# 2  2074.392523  25.981308  326.869159       NaN  61827.976636
# 3  5177.653631  20.055866  338.324022  2.960894  75466.363636
# 4  1516.567593  21.045062  228.317354  5.151007  50690.194987
# 5  3208.829842  18.758304  309.764946  4.660194  50811.082051
#
#             GenderPop
# ...

# %%
state1["males"], state1["female"] = state1.GenderPop.str.split("_").str[0],state1.GenderPop.str.split("_").str[1]

# %%
state1
# Out:
#    Unnamed: 0                 State  TotalPop     Hispanic        White  \
# 0           0              Colorado   5278906  2078.438003  6989.557166
# 1           1           Connecticut   3593222  1560.483092  6767.705314
# 2           2              Delaware    926454   882.476636  6463.271028
# 3           3  District of Columbia    647484   916.592179  3310.391061
# 4           4               Florida  19645772  2133.854267  5908.374880
# 5           5               Georgia  10006693   841.824221  5428.630557
#
#          Black     Native       Asian   Pacific        Income  \
# 0   354.637681  57.383253  266.199678       NaN  64657.801787
# 1  1034.806763  12.620773  402.198068  1.859903  76146.560588
# 2  2074.392523  25.981308  326.869159       NaN  61827.976636
# 3  5177.653631  20.055866  338.324022  2.960894  75466.363636
# 4  1516.567593  21.045062  228.317354  5.151007  50690.194987
# 5  3208.829842  18.758304  309.764946  4.660194  50811.082051
#
# ...

# %%
state1["males"] = state1["males"].str.replace("M", "").astype(int)

# %%
state1["female"] = state1["female"].str.replace("F", "").astype(int)

# %%
state1
# Out:
#    Unnamed: 0                 State  TotalPop     Hispanic        White  \
# 0           0              Colorado   5278906  2078.438003  6989.557166
# 1           1           Connecticut   3593222  1560.483092  6767.705314
# 2           2              Delaware    926454   882.476636  6463.271028
# 3           3  District of Columbia    647484   916.592179  3310.391061
# 4           4               Florida  19645772  2133.854267  5908.374880
# 5           5               Georgia  10006693   841.824221  5428.630557
#
#          Black     Native       Asian   Pacific        Income  \
# 0   354.637681  57.383253  266.199678       NaN  64657.801787
# 1  1034.806763  12.620773  402.198068  1.859903  76146.560588
# 2  2074.392523  25.981308  326.869159       NaN  61827.976636
# 3  5177.653631  20.055866  338.324022  2.960894  75466.363636
# 4  1516.567593  21.045062  228.317354  5.151007  50690.194987
# 5  3208.829842  18.758304  309.764946  4.660194  50811.082051
#
# ...

# %%
state1.drop(columns=["GenderPop"], inplace=True)

# %%
state1
# Out:
#    Unnamed: 0                 State  TotalPop     Hispanic        White  \
# 0           0              Colorado   5278906  2078.438003  6989.557166
# 1           1           Connecticut   3593222  1560.483092  6767.705314
# 2           2              Delaware    926454   882.476636  6463.271028
# 3           3  District of Columbia    647484   916.592179  3310.391061
# 4           4               Florida  19645772  2133.854267  5908.374880
# 5           5               Georgia  10006693   841.824221  5428.630557
#
#          Black     Native       Asian   Pacific        Income    males  \
# 0   354.637681  57.383253  266.199678       NaN  64657.801787  2648667
# 1  1034.806763  12.620773  402.198068  1.859903  76146.560588  1751607
# 2  2074.392523  25.981308  326.869159       NaN  61827.976636   448413
# 3  5177.653631  20.055866  338.324022  2.960894  75466.363636   306674
# 4  1516.567593  21.045062  228.317354  5.151007  50690.194987  9600009
# ...
